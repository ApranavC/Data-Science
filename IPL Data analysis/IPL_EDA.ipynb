# %%
import numpy as np
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
import warnings
warnings.filterwarnings("ignore")

# %%
d11_fantasy_points = pd.read_csv('/content/Fantasy_points.csv')

# %%
d11_credit_points = pd.read_csv('/content/credit_points.csv')

# %%
d11_credit_points.head()

# %%
d11_fantasy_points.head()
# Out:
#       Player Team  AGE    Role Special Feature Match_1 Match_2 Match_3  \
# 0   MS Dhoni  CSK   39  BAT/WK              MO      20      47      41
# 1     Watson  CSK   39     BAT              TO      17      46      21
# 2     Rayudu  CSK   34     BAT              TO      95     DNP     DNP
# 3  Du Plesis  CSK   36     BAT              MO     100     107      51
# 4      Vijay  CSK   36     BAT              TO       5      28      13
#
#   Match_4 Match_5 Match_6 Match_7 Match_8 Match_9 Match_10 Match_11 Match_12  \
# 0      71      12      54      32      29       7       50       24       26
# 1       5     112      78      21      53      46       14      DNP      DNP
# 2      19      12      37      50      52      66       17        6       50
# 3      38     112      40      20       2      96       15        5       51
# 4     DNP     DNP    DNP      DNP     DNP     DNP      DNP      DNP      DNP
#
#   Match_13 Match_14
# 0        5       12
# 1       21      DNP
# ...

# %%
d11_credit_points.tail()
# Out:
#          Player Team  Role  Credits
# 238    A Hosein  SRH  BOWL      7.5
# 239   F Farooqi  SRH  BOWL      7.0
# 240     K Tyagi  SRH  BOWL      6.5
# 241     M Dagar  SRH  BOWL      6.0
# 242  M Markande  SRH  BOWL      6.0

# %%
d11_fantasy_points.tail()
# Out:
#               Player Team  AGE  Role Special Feature Match_1 Match_2 Match_3  \
# 135      Shivam Mavi  KKR   21  BALL              TE      72       4      64
# 136       R Tripathi  KKR   29   BAT              MO     DNP     DNP     DNP
# 137       Tom Banton  KKR   21   BAT              TO     DNP     DNP     DNP
# 138  Prasidh Krishna  KKR   24  BALL              TE     DNP     DNP     DNP
# 139  Lockie Ferguson  KKR   29  BALL              TE     DNP     DNP     DNP
#
#     Match_4 Match_5 Match_6 Match_7 Match_8 Match_9 Match_10 Match_11  \
# 135       7      25     DNP     DNP      29      23      DNP      DNP
# 136      49     107       3      21      12      31        5       42
# 137     DNP     DNP     DNP      10     DNP     DNP       17      DNP
# 138     DNP     DNP      79      27      -2     DNP        4        2
# 139     DNP     DNP     DNP     DNP     DNP      85       53       29
#
#     Match_12 Match_13 Match_14
# 135      DNP      DNP       84
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Assuming df is your DataFrame and it's already loaded
# df = pd.read_csv('your_data.csv')

# Selecting the columns corresponding to past matches
matches = [f'Match_{i}' for i in range(1, 15)]

X = d11_fantasy_points['matches']  # Features
y = d11_fantasy_points['Match_15']  # Target variable
# Splitting the dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Creating the Linear Regression model
model = LinearRegression()

# Training the model
model.fit(X_train, y_train)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-44006652587a> in <cell line: 11>()
#       9 matches = [f'Match_{i}' for i in range(1, 15)]
#      10
# ---> 11 X = d11_fantasy_points['matches']  # Features
#      12 y = d11_fantasy_points['Match_15']  # Target variable
#      13 # Splitting the dataset into training set and test set
#
# NameError: name 'd11_fantasy_points' is not defined
